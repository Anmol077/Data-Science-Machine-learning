# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# # Series

# %%
list1 = ['harish','shweta','sravan']
print(list1)
type(list1)
# Out:
# ['harish', 'shweta', 'sravan']
# list

# %%
ser1 = pd.Series(list1)
print(ser1)
# Out:
# 0    harish
# 1    shweta
# 2    sravan
# dtype: object

# %%
type(ser1)
# Out:
# pandas.core.series.Series

# %%
list2 = ['idl2','id13','id14']

# %%
ser2 = pd.Series(list1,list2)

# %%
print(ser2)
# Out:
# idl2    harish
# id13    shweta
# id14    sravan
# dtype: object

# %%
import numpy as np
arr = np.array(list1)
pd.Series(arr)
# Out:
# 0    harish
# 1    shweta
# 2    sravan
# dtype: object

# %%
list1 = [10,20,30]
list_mul = list1*2
list_mul
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
list_str = ['a','b','c']
mul_list = list_str * 2
mul_list
# Out:
# ['a', 'b', 'c', 'a', 'b', 'c']

# %%
str_ser = pd.Series(list_str)
mul_ser = str_ser *2
mul_ser
# Out:
# 0    aa
# 1    bb
# 2    cc
# dtype: object

# %%
stud1=pd.Series([100,89],['maths','Science'])
stud2=pd.Series([90,92],['Science','maths'])
stud1+stud2
# Out:
# Science    179
# maths      192
# dtype: int64

# %%
stud1=pd.Series([100,89],['maths','Science'])
stud2=pd.Series([90,92],['English','maths'])
stud1+stud2
# Out:
# English      NaN
# Science      NaN
# maths      192.0
# dtype: float64

# %% [markdown]
# # Data Frame

# %%
emp_df = {'emp_name':['Sam','Mike','Frodo','Gibs'],'Salary':[20000,25000,30000,28000]}
print(emp_df)
type(emp_df)
# Out:
# {'emp_name': ['Sam', 'Mike', 'Frodo', 'Gibs'], 'Salary': [20000, 25000, 30000, 28000]}
# dict

# %%
df = pd.DataFrame(emp_df)
df
# Out:
#   emp_name  Salary
# 0      Sam   20000
# 1     Mike   25000
# 2    Frodo   30000
# 3     Gibs   28000

# %%
df.emp_name
# Out:
# 0      Sam
# 1     Mike
# 2    Frodo
# 3     Gibs
# Name: emp_name, dtype: object

# %%
df['emp_name']
# Out:
# 0      Sam
# 1     Mike
# 2    Frodo
# 3     Gibs
# Name: emp_name, dtype: object

# %%
df['emp_name'].values
# Out:
# array(['Sam', 'Mike', 'Frodo', 'Gibs'], dtype=object)

# %% [markdown]
# # Slicing

# %%
df.head(2)
# Out:
#   emp_name  Salary
# 0      Sam   20000
# 1     Mike   25000

# %%
df.tail(2)
# Out:
#   emp_name  Salary
# 2    Frodo   30000
# 3     Gibs   28000

# %%
df.loc[1:2]
# Out:
#   emp_name  Salary
# 1     Mike   25000
# 2    Frodo   30000

# %%
df.iloc[1:3]
# Out:
#          emp_name  Salary
# emp_name
# Mike         Mike   25000
# Frodo       Frodo   30000

# %% [markdown]
# # Merging

# %%
emp_df1 = pd.DataFrame({'emp_name':['Sam','Mike','Frodo','Gibs'],'Salary':[20000,25000,30000,28000]})
emp_df2 = pd.DataFrame({'emp_name':['Sam','Mike','Frodo','Gibs'],'Salary':[21000,25000,30000,28000]})
merg = pd.merge(emp_df1,emp_df2)
merg
# Out:
#   emp_name  Salary
# 0     Mike   25000
# 1    Frodo   30000
# 2     Gibs   28000

# %%
merg = pd.merge(emp_df1,emp_df2,on="emp_name")
merg
# Out:
#   emp_name  Salary_x  Salary_y
# 0      Sam     20000     21000
# 1     Mike     25000     25000
# 2    Frodo     30000     30000
# 3     Gibs     28000     28000

# %% [markdown]
# # Joining

# %%
df1 = pd.DataFrame({'emp_name':['Sam','Mike','Frodo','Gibs'],'Salary':[20000,25000,30000,28000]},index=[1,2,3,4])
df2 = pd.DataFrame({"Leaves":[10,20,30,25]},index=[1,2,3,5])
jn = df2.join(df1)
jn
# Out:
#    Leaves emp_name   Salary
# 1      10      Sam  20000.0
# 2      20     Mike  25000.0
# 3      30    Frodo  30000.0
# 5      25      NaN      NaN

# %%
updindex = df.set_index("emp_name")
updindex
# Out:
#           Salary
# emp_name
# Sam        20000
# Mike       25000
# Frodo      30000
# Gibs       28000

# %%
df
# Out:
#   emp_name  Salary
# 0      Sam   20000
# 1     Mike   25000
# 2    Frodo   30000
# 3     Gibs   28000

# %%
df.index = df['emp_name']
df.head()
# Out:
#          emp_name  Salary
# emp_name
# Sam           Sam   20000
# Mike         Mike   25000
# Frodo       Frodo   30000
# Gibs         Gibs   28000

# %%
conc = pd.concat((emp_df1,emp_df2))
conc
# Out:
#   emp_name  Salary
# 0      Sam   20000
# 1     Mike   25000
# 2    Frodo   30000
# 3     Gibs   28000
# 0      Sam   21000
# 1     Mike   25000
# 2    Frodo   30000
# 3     Gibs   28000

# %%
data = pd.read_csv('C:/Users/Anmol/Desktop/data science/google-play-store-apps/googleplaystore.csv')

# %%
data.shape
# Out:
# (10841, 13)

# %%
data.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
#     Read a comma-separated values (csv) file into DataFrame.
#
# ...

# %%
data.to_html('newData.html')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-34-379f39717375> in <module>
# ----> 1 data.to_html('newData.html')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, bold_rows, classes, escape, notebook, border, table_id, render_links)
#    2263                                            render_links=render_links)
#    2264         # TODO: a generic formatter wld b in DataFrameFormatter
# -> 2265         formatter.to_html(classes=classes, notebook=notebook, border=border)
#    2266
#    2267         if buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_html(self, classes, notebook, border)
#     732         elif isinstance(self.buf, compat.string_types):
# ...

# %%
html = data.to_html()
with open("mypage.html", "w",encoding="utf-8)") as file:
    file.write(html)
